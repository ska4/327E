# %%
# %env INSTANCE=my
# Out:
# env: INSTANCE=my

# %%
# !mysql < /home/jupyter/sakila/sakila-database.sql

# %%
# !mysql < /home/jupyter/sakila/sakila-data.sql

# %%
# !mysql sakila -e "SELECT COUNT(*) FROM actor;"
# !mysql sakila -e "SELECT COUNT(*) FROM customer;"
# !mysql sakila -e "SELECT COUNT(*) FROM city;"
# !mysql sakila -e "SELECT COUNT(*) FROM address;"
# !mysql sakila -e "SELECT COUNT(*) FROM country;"
# Out:
# +----------+
# | COUNT(*) |
# +----------+
# |      200 |
# +----------+
# +----------+
# | COUNT(*) |
# +----------+
# |      599 |
# +----------+
# +----------+
# | COUNT(*) |
# +----------+
# |      600 |
# +----------+
# +----------+
# | COUNT(*) |
# +----------+
# |      603 |
# +----------+
# +----------+
# | COUNT(*) |
# +----------+
# |      109 |
# +----------+

# %%
# !mysql sakila -e "SELECT actor_id, first_name, last_name FROM actor LIMIT 5;"
# !mysql sakila -e "SELECT customer_id, first_name, last_name FROM customer LIMIT 5;"
# !mysql sakila -e "SELECT film_id, title, release_year FROM film LIMIT 5;"
# !mysql sakila -e "SELECT rental_id, rental_date, inventory_id FROM rental LIMIT 5;"
# !mysql sakila -e "SELECT staff_id, first_name, last_name FROM staff LIMIT 5;"
# Out:
# +----------+------------+--------------+
# | actor_id | first_name | last_name    |
# +----------+------------+--------------+
# |        1 | PENELOPE   | GUINESS      |
# |        2 | NICK       | WAHLBERG     |
# |        3 | ED         | CHASE        |
# |        4 | JENNIFER   | DAVIS        |
# |        5 | JOHNNY     | LOLLOBRIGIDA |
# +----------+------------+--------------+
# +-------------+------------+-----------+
# | customer_id | first_name | last_name |
# +-------------+------------+-----------+
# |           1 | MARY       | SMITH     |
# |           2 | PATRICIA   | JOHNSON   |
# |           3 | LINDA      | WILLIAMS  |
# |           4 | BARBARA    | JONES     |
# |           5 | ELIZABETH  | BROWN     |
# +-------------+------------+-----------+
# +---------+------------------+--------------+
# | film_id | title            | release_year |
# +---------+------------------+--------------+
# |       1 | ACADEMY DINOSAUR |         2006 |
# ...

# %%
#Gets all rental_dates with inventory_id that is greater than 4500 and orders them by inventory_id
# !mysql sakila -e "SELECT rental_date, inventory_id FROM rental WHERE inventory_id > 4500 ORDER BY inventory_id;"
# Out:
# +---------------------+--------------+
# | rental_date         | inventory_id |
# +---------------------+--------------+
# | 2005-08-02 03:48:17 |         4501 |
# | 2005-08-19 08:07:50 |         4501 |
# | 2005-05-25 19:12:42 |         4502 |
# | 2005-06-15 16:06:29 |         4502 |
# | 2005-07-06 05:37:18 |         4502 |
# | 2005-08-02 04:24:23 |         4502 |
# | 2005-08-17 09:51:54 |         4502 |
# | 2005-07-12 16:06:00 |         4503 |
# | 2005-07-27 19:48:12 |         4503 |
# | 2005-08-23 01:44:43 |         4503 |
# | 2005-06-15 01:24:20 |         4504 |
# | 2005-07-06 13:04:35 |         4504 |
# | 2005-08-01 09:31:00 |         4504 |
# | 2005-08-20 08:26:32 |         4504 |
# | 2005-07-28 18:49:43 |         4505 |
# | 2005-08-22 21:34:00 |         4505 |
# | 2005-06-18 08:51:29 |         4506 |
# | 2005-07-06 17:24:49 |         4506 |
# | 2005-07-27 07:00:37 |         4506 |
# | 2005-08-21 06:23:29 |         4506 |
# | 2005-05-27 16:31:05 |         4507 |
# ...

# %%
#Adds a new actor into the actor table named LeBron James
# !mysql sakila -e "INSERT INTO actor (first_name, last_name) VALUES ('LeBron', 'James');"

# %%
#Changes last name to Brady of row of person with staff_id being 1
# !mysql sakila -e "UPDATE staff SET last_name = 'Brady' WHERE staff_id = 1;"

# %%
#Deletes the inventory row where store_id is 200
# !mysql sakila -e "DELETE FROM inventory WHERE store_id = 200;"
